# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV, cross_val_score, train_test_split, RandomizedSearchCV
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from imblearn.over_sampling import SMOTE
from sklearn.feature_selection import SelectKBest, chi2, mutual_info_classif
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings("ignore")

import numpy as np

# Load train and test data
train_data = pd.read_csv(r'C:\Users\marco\OneDrive - usp.br\Área de Trabalho\mestrado\resultados\gray_treino.csv', engine='python', sep=';')
test_data = pd.read_csv(r'C:\Users\marco\OneDrive - usp.br\Área de Trabalho\mestrado\resultados\gray_teste.csv', engine='python', sep=';')

# Separate features and labels
X_train = train_data.drop('Grade', axis=1)
y_train = train_data['Grade']
X_test = test_data.drop('Grade', axis=1)
y_test = test_data['Grade']

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
best_k = None
best_acc = 0.0
# Apply SMOTE to balance the training data
smote = SMOTE(k_neighbors=2)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_scaled, y_train)
best_k = None
best_acc = 0.0
# Apply SMOTE to balance the training data
smote = SMOTE(k_neighbors=2)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

for K in range(1,21):
    knn = KNeighborsClassifier(n_neighbors = K)
    cv_accuracy = cross_val_score(knn, X_train_resampled, y_train_resampled, cv=10, scoring='accuracy')
    mean_cv_accuracy = cv_accuracy.mean()
    dev_cv_accuracy = cv_accuracy.std()
    print(f'K = {K}: ({100*mean_cv_accuracy:.2f} ± {100*dev_cv_accuracy:.2f})%' )
    if best_acc < cv_accuracy.mean():
        best_acc = round(100*cv_accuracy.mean(),2)
        best_k = K
    
print(f'K = {best_k} -> acurácia = {best_acc}%')

best_acc = 0.0
best_n = None
for n in range(5,31,5):
    # Use SelectKBest to select the top k features
    k_best = SelectKBest(score_func=mutual_info_classif, k=n)  # Change k to the desired number of features
    X_train_k_best = k_best.fit_transform(X_train_resampled, y_train_resampled)
    X_test_k_best = k_best.transform(X_test)
    #Fit the Naive_Bayes 
    knn = KNeighborsClassifier(n_neighbors=best_k)
    fit = knn.fit(X_train_k_best, y_train_resampled)



    # Get the scores of the selected features
    feature_scores = k_best.scores_

    # Get the feature names
    feature_names = X_train.columns

    
    # Sort features by their scores
    sorted_indices = feature_scores.argsort()[::-1][:n]  # Select the top n features
    sorted_feature_names = [feature_names[i] for i in sorted_indices]
    sorted_feature_scores = feature_scores[sorted_indices]

    # Plot feature scores for the top n features (horizontal bars)
    plt.figure(figsize=(10, 6))
    plt.barh(range(n), sorted_feature_scores)
    plt.yticks(range(n), sorted_feature_names)
    plt.xlabel('Score')
    plt.ylabel('Features')
    plt.title(f'Top {n} Feature Scores')
    plt.gca().invert_yaxis()  # Invert the y-axis to display the highest score at the top
    plt.show()

    # Print the top k features
    selected_feature_indices = k_best.get_support(indices=True)
    selected_feature_names = [feature_names[i] for i in selected_feature_indices]
    print(f"Selected {len(selected_feature_names)} features: {', '.join(selected_feature_names)}")
    # Make predictions on the test data
    y_pred = fit.predict(X_test_k_best)

    cv_accuracy = cross_val_score(knn, X_train_k_best, y_train_resampled, cv=5, scoring='accuracy')
    mean_cv_accuracy = cv_accuracy.mean()
    dev_cv_accuracy = cv_accuracy.std()
    print(f'({100*mean_cv_accuracy:.2f} ± {100*dev_cv_accuracy:.2f})%' )

    # Accuracy with cross-validation
    cv_accuracy = cross_val_score(knn, X_test_k_best, y_test, cv=5, scoring='accuracy')
    mean_cv_accuracy = cv_accuracy.mean()
    dev_cv_accuracy = cv_accuracy.std()
    print(f'({100*mean_cv_accuracy:.2f} ± {100*dev_cv_accuracy:.2f})%' )
    if best_acc < cv_accuracy.mean():
        best_acc = cv_accuracy.mean()
        best_n = n
    
    # Classification report
    classification_rep = classification_report(y_test, y_pred)
    print(classification_rep)
    # Confusion matrix
    # Confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    
    # Normalize the confusion matrix
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    # Display the normalized confusion matrix
    disp = ConfusionMatrixDisplay(confusion_matrix=cm_normalized, display_labels=[0, 1,2,3])
    disp.plot()
    plt.show()
    from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
    import matplotlib.pyplot as plt

    # Calcular a matriz de confusão
    cm = confusion_matrix(y_test, y_pred, normalize='true')

    # Criar um heatmap
    plt.figure(figsize=(8, 6))
    plt.imshow(cm, cmap='Blues', interpolation='nearest')
    plt.title('Matriz de Confusão Normalizada')
    plt.colorbar()

    # Adicionar rótulos aos eixos
    class_labels = ['0','1','2','3']  # Substitua pelos seus rótulos
    # Configure o tamanho da fonte
    a = True
    
    plt.rc('font', size=20)  # Defina o tamanho da fonte desejado
    
    tick_marks = np.arange(len(class_labels))
    plt.xticks(tick_marks, class_labels, rotation=45)
    plt.yticks(tick_marks, class_labels)

    # Adicionar os valores nas células
    for i in range(len(class_labels)):
        for j in range(len(class_labels)):
            plt.text(j, i, f"{cm[i, j]:.2f}", horizontalalignment="center", color="#ECAEAE")

    plt.tight_layout()
    plt.xlabel('Rótulos Preditos')
    plt.ylabel('Rótulos Verdadeiros')
    plt.show()
    plt.rc('font', size=10)
print(f'best n = {best_n}, best accurancy = {best_acc}')
# Out:
# K = 1: (81.61 ± 4.54)%
# K = 2: (76.71 ± 4.26)%
# K = 3: (79.23 ± 3.11)%
# K = 4: (75.39 ± 3.54)%
# K = 5: (75.91 ± 4.55)%
# K = 6: (74.59 ± 4.38)%
# K = 7: (75.12 ± 4.59)%
# K = 8: (74.19 ± 4.28)%
# K = 9: (72.86 ± 4.26)%
# K = 10: (71.68 ± 3.43)%
# K = 11: (71.81 ± 3.68)%
# K = 12: (71.02 ± 4.48)%
# K = 13: (71.28 ± 4.31)%
# K = 14: (71.55 ± 4.44)%
# K = 15: (71.42 ± 4.75)%
# K = 16: (70.10 ± 4.25)%
# K = 17: (69.83 ± 4.47)%
# K = 18: (69.84 ± 4.68)%
# K = 19: (70.10 ± 4.20)%
# K = 20: (69.57 ± 4.66)%
# K = 1 -> acurácia = 81.61%
# Selected 5 features: original_gldm_DependenceNonUniformity, original_glrlm_RunVariance, original_glszm_LargeAreaEmphasis, original_glszm_LargeAreaHighGrayLevelEmphasis, original_glszm_ZoneVariance
# (79.76 ± 4.20)%
# (68.93 ± 15.67)%
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.81      0.85        21
#          1.0       0.55      0.46      0.50        13
#          2.0       0.12      0.33      0.18         3
#          3.0       0.00      0.00      0.00         1
#
#     accuracy                           0.63        38
#    macro avg       0.39      0.40      0.38        38
# weighted avg       0.69      0.63      0.66        38
# Selected 10 features: original_firstorder_TotalEnergy, original_gldm_DependenceNonUniformity, original_gldm_GrayLevelNonUniformity, original_glrlm_RunEntropy, original_glrlm_RunPercentage, original_glrlm_RunVariance, original_glszm_LargeAreaEmphasis, original_glszm_LargeAreaHighGrayLevelEmphasis, original_glszm_ZoneVariance, original_ngtdm_Coarseness
# (81.34 ± 3.03)%
# (73.21 ± 9.72)%
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.71      0.81        21
#          1.0       0.59      0.77      0.67        13
#          2.0       0.33      0.33      0.33         3
#          3.0       0.50      1.00      0.67         1
#
#     accuracy                           0.71        38
#    macro avg       0.59      0.70      0.62        38
# weighted avg       0.76      0.71      0.72        38
# Selected 15 features: original_firstorder_Energy, original_firstorder_TotalEnergy, original_gldm_DependenceNonUniformity, original_gldm_GrayLevelNonUniformity, original_gldm_GrayLevelVariance, original_glcm_Idn, original_glcm_SumSquares, original_glrlm_LongRunEmphasis, original_glrlm_RunEntropy, original_glrlm_RunPercentage, original_glrlm_RunVariance, original_glszm_LargeAreaEmphasis, original_glszm_LargeAreaHighGrayLevelEmphasis, original_glszm_ZoneVariance, original_ngtdm_Coarseness
# (79.62 ± 3.42)%
# (73.21 ± 9.72)%
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.76      0.84        21
#          1.0       0.62      0.77      0.69        13
#          2.0       0.33      0.33      0.33         3
#          3.0       0.50      1.00      0.67         1
#
#     accuracy                           0.74        38
#    macro avg       0.60      0.72      0.63        38
# weighted avg       0.77      0.74      0.75        38
# Selected 20 features: original_firstorder_Energy, original_firstorder_InterquartileRange, original_firstorder_TotalEnergy, original_gldm_DependenceNonUniformity, original_gldm_DependenceNonUniformityNormalized, original_gldm_GrayLevelNonUniformity, original_gldm_GrayLevelVariance, original_glcm_DifferenceVariance, original_glcm_Idn, original_glcm_SumSquares, original_glrlm_LongRunEmphasis, original_glrlm_RunEntropy, original_glrlm_RunPercentage, original_glrlm_RunVariance, original_glszm_LargeAreaEmphasis, original_glszm_LargeAreaHighGrayLevelEmphasis, original_glszm_LargeAreaLowGrayLevelEmphasis, original_glszm_ZoneVariance, original_ngtdm_Coarseness, original_ngtdm_Strength
# (80.28 ± 3.74)%
# (73.21 ± 9.72)%
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.76      0.84        21
#          1.0       0.62      0.77      0.69        13
#          2.0       0.33      0.33      0.33         3
#          3.0       0.50      1.00      0.67         1
#
#     accuracy                           0.74        38
#    macro avg       0.60      0.72      0.63        38
# weighted avg       0.77      0.74      0.75        38
# Selected 25 features: original_firstorder_Energy, original_firstorder_InterquartileRange, original_firstorder_TotalEnergy, original_gldm_DependenceNonUniformity, original_gldm_DependenceNonUniformityNormalized, original_gldm_GrayLevelNonUniformity, original_gldm_GrayLevelVariance, original_glcm_Contrast, original_glcm_DifferenceVariance, original_glcm_Idn, original_glcm_SumSquares, original_glrlm_LongRunEmphasis, original_glrlm_LongRunHighGrayLevelEmphasis, original_glrlm_RunEntropy, original_glrlm_RunLengthNonUniformityNormalized, original_glrlm_RunPercentage, original_glrlm_RunVariance, original_glszm_LargeAreaEmphasis, original_glszm_LargeAreaHighGrayLevelEmphasis, original_glszm_LargeAreaLowGrayLevelEmphasis, original_glszm_SmallAreaLowGrayLevelEmphasis, original_glszm_ZoneVariance, original_ngtdm_Coarseness, original_ngtdm_Contrast, original_ngtdm_Strength
# (80.28 ± 3.74)%
# (73.21 ± 9.72)%
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.76      0.84        21
#          1.0       0.62      0.77      0.69        13
#          2.0       0.33      0.33      0.33         3
#          3.0       0.50      1.00      0.67         1
#
#     accuracy                           0.74        38
#    macro avg       0.60      0.72      0.63        38
# weighted avg       0.77      0.74      0.75        38
# Selected 30 features: original_firstorder_Energy, original_firstorder_InterquartileRange, original_firstorder_Minimum, original_firstorder_TotalEnergy, original_gldm_DependenceNonUniformity, original_gldm_DependenceNonUniformityNormalized, original_gldm_GrayLevelNonUniformity, original_gldm_GrayLevelVariance, original_gldm_LargeDependenceEmphasis, original_glcm_Contrast, original_glcm_DifferenceVariance, original_glcm_Idm, original_glcm_Idn, original_glcm_InverseVariance, original_glcm_SumSquares, original_glrlm_GrayLevelNonUniformityNormalized, original_glrlm_LongRunEmphasis, original_glrlm_LongRunHighGrayLevelEmphasis, original_glrlm_RunEntropy, original_glrlm_RunLengthNonUniformityNormalized, original_glrlm_RunPercentage, original_glrlm_RunVariance, original_glszm_LargeAreaEmphasis, original_glszm_LargeAreaHighGrayLevelEmphasis, original_glszm_LargeAreaLowGrayLevelEmphasis, original_glszm_SmallAreaLowGrayLevelEmphasis, original_glszm_ZoneVariance, original_ngtdm_Coarseness, original_ngtdm_Contrast, original_ngtdm_Strength
# (80.28 ± 3.74)%
# (73.21 ± 9.72)%
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.76      0.84        21
#          1.0       0.62      0.77      0.69        13
#          2.0       0.33      0.33      0.33         3
#          3.0       0.50      1.00      0.67         1
#
#     accuracy                           0.74        38
#    macro avg       0.60      0.72      0.63        38
# weighted avg       0.77      0.74      0.75        38
# best n = 10, best accurancy = 0.7321428571428571
